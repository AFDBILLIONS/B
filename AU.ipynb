# %% [markdown]
# <a href="https://colab.research.google.com/github/AFDBILLIONS/Python-data-analysis-basic/blob/master/AU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello")
# Out:
# hello

# %%
minuters_in_a_day =24*60
minuters_in_a_day
# Out:
# 1440

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='y', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
